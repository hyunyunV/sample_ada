# %%
from scipy import stats
import pandas as pd
from Oncetrain import * 
from Stat import *

# %%
Datalenlist = [1000,1500,2500,5500,10500]
#Datalenlist = ["1:1","2:1","4:1","10:1","20:1"]
auc_res = readexcel('Result/AUCfit',Datalenlist)
acc_res = readexcel('Result/ACCfit',Datalenlist)
def_res = readexcel('Result/defalutfit',Datalenlist)
ths_res = readexcel('Result/defalutfiThreshold',Datalenlist)

# %%
acc_res = BeClass(acc_res)
acc_res = DoDivList(acc_res)

# %%
auc_res = BeClass(auc_res)
auc_res = DoDivList(auc_res)

# %%
def_res = BeClass(def_res)
def_res = DoDivList(def_res)

# %%
ths_res = BeClass(ths_res)
ths_res = DoDivList(ths_res)

# %%
df = PrintTtestStat(ths_res,acc_res,Datalenlist,"DEFAULT", "ACCFIT")
FinalForm = pd.concat(df)
FinalForm
# Out:
# 1000	DEFAULT & ACCFIT	Measure : ACC
#
# LeveneResult -- stat : 5.958649, p-value : 0.017719
#
# False
#
# statistic : -2 , pvalue : 0.0085795
#
# 1000	DEFAULT & ACCFIT	Measure : AUC
#
# LeveneResult -- stat : 5.828213, p-value : 0.018948
#
# False
#
# statistic : -3 , pvalue : 0.0047187
#
# 1000	DEFAULT & ACCFIT	Measure : GEOACC
#
# LeveneResult -- stat : 6.017184, p-value : 0.017195
#
# False
#
# statistic : -2 , pvalue : 0.0081551
#
# 1500	DEFAULT & ACCFIT	Measure : ACC
#
# LeveneResult -- stat : 0.950344, p-value : 0.333680
#
# True
#
# statistic : -3 , pvalue : 0.0010152
#
# 1500	DEFAULT & ACCFIT	Measure : AUC
#
# LeveneResult -- stat : 2.254371, p-value : 0.138662
#
# True
#
# statistic : -2 , pvalue : 0.0119030
#
# 1500	DEFAULT & ACCFIT	Measure : GEOACC
#
# LeveneResult -- stat : 1.663104, p-value : 0.202304
#
# True
#
# statistic : -3 , pvalue : 0.0016826
#
# 2500	DEFAULT & ACCFIT	Measure : ACC
#
# LeveneResult -- stat : 2.561940, p-value : 0.114898
#
# True
#
# statistic : -3 , pvalue : 0.0012658
#
# 2500	DEFAULT & ACCFIT	Measure : AUC
#
# LeveneResult -- stat : 4.444749, p-value : 0.039340
#
# False
#
# statistic : -2 , pvalue : 0.0121894
#
# 2500	DEFAULT & ACCFIT	Measure : GEOACC
#
# LeveneResult -- stat : 4.517881, p-value : 0.037812
#
# False
#
# statistic : -2 , pvalue : 0.0054661
#
# 5500	DEFAULT & ACCFIT	Measure : ACC
#
# LeveneResult -- stat : 2.869465, p-value : 0.095639
#
# True
#
# statistic : -3 , pvalue : 0.0015344
#
# 5500	DEFAULT & ACCFIT	Measure : AUC
#
# LeveneResult -- stat : 3.609073, p-value : 0.062441
#
# True
#
# statistic : -2 , pvalue : 0.0149515
#
# 5500	DEFAULT & ACCFIT	Measure : GEOACC
#
# LeveneResult -- stat : 6.496198, p-value : 0.013479
#
# False
#
# statistic : -2 , pvalue : 0.0065978
#
# 10500	DEFAULT & ACCFIT	Measure : ACC
#
# LeveneResult -- stat : 4.322441, p-value : 0.042045
#
# False
#
# statistic : -3 , pvalue : 0.0003990
#
# 10500	DEFAULT & ACCFIT	Measure : AUC
#
# LeveneResult -- stat : 11.979054, p-value : 0.001016
#
# False
#
# statistic : -3 , pvalue : 0.0030479
#
# 10500	DEFAULT & ACCFIT	Measure : GEOACC
#
# LeveneResult -- stat : 7.779111, p-value : 0.007138
#
# False
#
# statistic : -2 , pvalue : 0.0097319
#                     ACC    AUC  GEOACC
# 1:1  DEFAULT      0.867  0.924   0.866
#      ACCFIT       0.905  0.960   0.905
#      t-statistic -2.769 -3.009  -2.789
#      p-value      0.009  0.005   0.008
# 2:1  DEFAULT      0.834  0.903   0.833
#      ACCFIT       0.884  0.943   0.880
#      t-statistic -3.461 -2.597  -3.295
#      p-value      0.001  0.012   0.002
# 4:1  DEFAULT      0.805  0.878   0.805
#      ACCFIT       0.850  0.919   0.847
#      t-statistic -3.389 -2.627  -2.931
#      p-value      0.001  0.012   0.005
# 10:1 DEFAULT      0.756  0.828   0.755
#      ACCFIT       0.796  0.867   0.793
#      t-statistic -3.326 -2.508  -2.857
#      p-value      0.002  0.015   0.007
# 20:1 DEFAULT      0.694  0.760   0.701
#      ACCFIT       0.754  0.826   0.752
#      t-statistic -3.798 -3.147  -2.693
#      p-value      0.000  0.003   0.010

# %%
df = PrintTtestStat(ths_res,auc_res,Datalenlist,"DefualtThreshold", "AUCFIT")
FinalForm = pd.concat(df)
FinalForm
# Out:
# 1000	DefualtThreshold & AUCFIT	Measure : ACC
#
# LeveneResult -- stat : 1.840630, p-value : 0.180134
#
# True
#
# statistic : -1 , pvalue : 0.1154346
#
# 1000	DefualtThreshold & AUCFIT	Measure : AUC
#
# LeveneResult -- stat : 1.670570, p-value : 0.201308
#
# True
#
# statistic : -2 , pvalue : 0.0382842
#
# 1000	DefualtThreshold & AUCFIT	Measure : GEOACC
#
# LeveneResult -- stat : 1.741394, p-value : 0.192148
#
# True
#
# statistic : -1 , pvalue : 0.1253452
#
# 1500	DefualtThreshold & AUCFIT	Measure : ACC
#
# LeveneResult -- stat : 1.250360, p-value : 0.268094
#
# True
#
# statistic : -2 , pvalue : 0.0083570
#
# 1500	DefualtThreshold & AUCFIT	Measure : AUC
#
# LeveneResult -- stat : 1.848260, p-value : 0.179248
#
# True
#
# statistic : -2 , pvalue : 0.0209702
#
# 1500	DefualtThreshold & AUCFIT	Measure : GEOACC
#
# LeveneResult -- stat : 1.278412, p-value : 0.262848
#
# True
#
# statistic : -2 , pvalue : 0.0091747
#
# 2500	DefualtThreshold & AUCFIT	Measure : ACC
#
# LeveneResult -- stat : 2.825245, p-value : 0.098171
#
# True
#
# statistic : -2 , pvalue : 0.0067256
#
# 2500	DefualtThreshold & AUCFIT	Measure : AUC
#
# LeveneResult -- stat : 3.491870, p-value : 0.066724
#
# True
#
# statistic : -2 , pvalue : 0.0129475
#
# 2500	DefualtThreshold & AUCFIT	Measure : GEOACC
#
# LeveneResult -- stat : 2.437832, p-value : 0.123880
#
# True
#
# statistic : -2 , pvalue : 0.0311535
#
# 5500	DefualtThreshold & AUCFIT	Measure : ACC
#
# LeveneResult -- stat : 6.038749, p-value : 0.017006
#
# False
#
# statistic : -3 , pvalue : 0.0008991
#
# 5500	DefualtThreshold & AUCFIT	Measure : AUC
#
# LeveneResult -- stat : 2.692733, p-value : 0.106219
#
# True
#
# statistic : -3 , pvalue : 0.0017139
#
# 5500	DefualtThreshold & AUCFIT	Measure : GEOACC
#
# LeveneResult -- stat : 3.884526, p-value : 0.053511
#
# True
#
# statistic : -2 , pvalue : 0.0039908
#
# 10500	DefualtThreshold & AUCFIT	Measure : ACC
#
# LeveneResult -- stat : 19.187870, p-value : 0.000050
#
# False
#
# statistic : -5 , pvalue : 0.0000015
#
# 10500	DefualtThreshold & AUCFIT	Measure : AUC
#
# LeveneResult -- stat : 19.244640, p-value : 0.000049
#
# False
#
# statistic : -4 , pvalue : 0.0000413
#
# 10500	DefualtThreshold & AUCFIT	Measure : GEOACC
#
# LeveneResult -- stat : 20.039213, p-value : 0.000036
#
# False
#
# statistic : -4 , pvalue : 0.0002490
#                          ACC    AUC  GEOACC
# 1:1  DefualtThreshold  0.867  0.924   0.866
#      AUCFIT            0.892  0.952   0.890
#      t-statistic      -1.598 -2.120  -1.555
#      p-value           0.115  0.038   0.125
# 2:1  DefualtThreshold  0.834  0.903   0.833
#      AUCFIT            0.873  0.940   0.872
#      t-statistic      -2.731 -2.373  -2.696
#      p-value           0.008  0.021   0.009
# 4:1  DefualtThreshold  0.805  0.878   0.805
#      AUCFIT            0.843  0.919   0.839
#      t-statistic      -2.811 -2.564  -2.209
#      p-value           0.007  0.013   0.031
# 10:1 DefualtThreshold  0.756  0.828   0.755
#      AUCFIT            0.799  0.879   0.796
#      t-statistic      -3.644 -3.289  -2.999
#      p-value           0.001  0.002   0.004
# 20:1 DefualtThreshold  0.694  0.760   0.701
#      AUCFIT            0.775  0.853   0.771
#      t-statistic      -5.789 -4.674  -4.044
#      p-value           0.000  0.000   0.000

# %%
df = PrintMannStat(def_res,auc_res,Datalenlist,"DEFAULTFIT", "AUCFIT")
# Out:
# 1000	DEFAULTFIT & AUCFIT	Measure : ACC
#
#
# statistic : 248 , pvalue : 0.0027932
#
# 1000	DEFAULTFIT & AUCFIT	Measure : AUC
#
#
# statistic : 254 , pvalue : 0.0038466
#
# 1000	DEFAULTFIT & AUCFIT	Measure : GEOACC
#
#
# statistic : 240 , pvalue : 0.0019411
#
# 1500	DEFAULTFIT & AUCFIT	Measure : ACC
#
#
# statistic : 0 , pvalue : 0.0000000
#
# 1500	DEFAULTFIT & AUCFIT	Measure : AUC
#
#
# statistic : 302 , pvalue : 0.0292054
#
# 1500	DEFAULTFIT & AUCFIT	Measure : GEOACC
#
#
# statistic : 0 , pvalue : 0.0000000
#
# 2500	DEFAULTFIT & AUCFIT	Measure : ACC
#
#
# statistic : 90 , pvalue : 0.0000000
#
# 2500	DEFAULTFIT & AUCFIT	Measure : AUC
#
#
# statistic : 206 , pvalue : 0.0003182
#
# 2500	DEFAULTFIT & AUCFIT	Measure : GEOACC
#
#
# statistic : 0 , pvalue : 0.0000000
#
# 5500	DEFAULTFIT & AUCFIT	Measure : ACC
#
#
# statistic : 900 , pvalue : 0.0000000
#
# 5500	DEFAULTFIT & AUCFIT	Measure : AUC
#
#
# statistic : 140 , pvalue : 0.0000047
#
# 5500	DEFAULTFIT & AUCFIT	Measure : GEOACC
#
#
# statistic : 0 , pvalue : 0.0000000
#
# 10500	DEFAULTFIT & AUCFIT	Measure : ACC
#
#
# statistic : 900 , pvalue : 0.0000000
#
# 10500	DEFAULTFIT & AUCFIT	Measure : AUC
#
#
# statistic : 180 , pvalue : 0.0000677
#
# 10500	DEFAULTFIT & AUCFIT	Measure : GEOACC
#
#
# statistic : 0 , pvalue : 0.0000000

# %%
df[0]
# Out:
#                  ACC      AUC   GEOACC
# DEFAULTFIT     0.847    0.933    0.836
# AUCFIT         0.896    0.956    0.895
# u-statistic  248.000  254.000  240.000
# p-value        0.003    0.004    0.002

# %%
Datalenlist = [1000,1500,2500,5500,10500]
auc_res = readexcel('Result/AUCfit',Datalenlist)
def_res = readexcel('Result/defalutfit',Datalenlist)
valaccauc(def_ress)
valaccauc(auc_ress)
# Out:
# ------------------------------
#  acc_mean : 0.85
#  acc_std : 0.07
#  auc_mean : 0.93
#  auc_std : 0.04
#  geoacc_mean : 0.84
#  geoacc_std : 0.09
# ------------------------------
# ------------------------------
#  acc_mean : 0.67
#  acc_std : 0.00
#  auc_mean : 0.91
#  auc_std : 0.05
#  geoacc_mean : 0.00
#  geoacc_std : 0.00
# ------------------------------
# ------------------------------
#  acc_mean : 0.80
#  acc_std : 0.00
#  auc_mean : 0.87
#  auc_std : 0.06
#  geoacc_mean : 0.00
#  geoacc_std : 0.00
# ------------------------------
# ------------------------------
#  acc_mean : 0.91
#  acc_std : 0.00
#  auc_mean : 0.81
#  auc_std : 0.06
#  geoacc_mean : 0.00
#  geoacc_std : 0.00
# ------------------------------
# ------------------------------
#  acc_mean : 0.95
#  acc_std : 0.00
#  auc_mean : 0.79
#  auc_std : 0.06
#  geoacc_mean : 0.00
#  geoacc_std : 0.00
# ------------------------------
# ------------------------------
#  acc_mean : 0.90
#  acc_std : 0.04
#  auc_mean : 0.96
#  auc_std : 0.03
#  geoacc_mean : 0.89
#  geoacc_std : 0.04
# ------------------------------
# ------------------------------
#  acc_mean : 0.88
#  acc_std : 0.03
#  auc_mean : 0.94
#  auc_std : 0.03
#  geoacc_mean : 0.87
#  geoacc_std : 0.03
# ------------------------------
# ------------------------------
#  acc_mean : 0.85
#  acc_std : 0.03
#  auc_mean : 0.92
#  auc_std : 0.03
#  geoacc_mean : 0.84
#  geoacc_std : 0.04
# ------------------------------
# ------------------------------
#  acc_mean : 0.80
#  acc_std : 0.03
#  auc_mean : 0.87
#  auc_std : 0.04
#  geoacc_mean : 0.79
#  geoacc_std : 0.04
# ------------------------------
# ------------------------------
#  acc_mean : 0.77
#  acc_std : 0.03
#  auc_mean : 0.85
#  auc_std : 0.04
#  geoacc_mean : 0.77
#  geoacc_std : 0.04
# ------------------------------

# %%
df[0] = round(df[0],3)

# %%
df[0]
# Out:
#                ACC    AUC  GEOACC
# DEFAULTFIT   0.851  0.924   0.843
# AUCFIT       0.892  0.952   0.890
# t-statistic -2.575 -2.120  -2.847
# p-value      0.013  0.038   0.006

# %%
stats.ttest_ind(x,y)

# %%
[[3,2,4][0]]
# Out:
# [3]
